# %% [markdown]
# # Lab 1 — Getting hands-on with images
# **Student name:** Joud Thaher
#
# **Course:** Computer Vision

# %%
import os
import numpy as np
from PIL import Image, ImageDraw
import cv2

# %% [markdown]
# the code above imports the packages we installed for the lab and being able to run them without erros mean the jupyter notebook is correctly connected to the env and packages.

# %%
#os.makedirs("./outputs", exist_ok=True)
#print("outputs folder under Lab1 is ready")

# %% [markdown]
# the above code makes a new outputs folder under the Lab1 folder, but i wanted to make a shared outputs folder so i will put ../outputs instead of ./outputs to go back to root folder as shown in the following block of code.

# %%
os.makedirs("../outputs", exist_ok=True)
print("shared outputs folder is ready")

# %% [markdown]
# Note on running (a problem I faced while trying) : when u restart the kernel and run a specific block of code it will give an error if the code does not have the imports, so u could either run all at once so that it runs correctly or just run the block of codes u want in case there are some blocks u don't need. So far, i will comment the previous code so that it doesn't generate a new outputs folder each time under the Lab1 folder.

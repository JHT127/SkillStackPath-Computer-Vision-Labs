# %% [markdown]
# ## My First Notebook
# This is my first time trying to write my own notebook.

# %%
x = 7
y = 12
print("The sum is of", x, "and", y, "is : ",  x+y)
# Out:
# The sum is of 7 and 12 is :  19

# %% [markdown]
# ### My Observation
# The code above adds two numbers and prints the result.
